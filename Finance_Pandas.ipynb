# %%
# !pip install yfinance
# !pip install matplotlib
# Out:
# Requirement already satisfied: yfinance in c:\users\fadi\anaconda3\lib\site-packages (0.2.31)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\fadi\anaconda3\lib\site-packages (from yfinance) (2.1.2)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\fadi\anaconda3\lib\site-packages (from yfinance) (1.26.1)
# Requirement already satisfied: requests>=2.31 in c:\users\fadi\anaconda3\lib\site-packages (from yfinance) (2.31.0)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\fadi\anaconda3\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\fadi\anaconda3\lib\site-packages (from yfinance) (4.9.3)
# Requirement already satisfied: appdirs>=1.4.4 in c:\users\fadi\anaconda3\lib\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: pytz>=2022.5 in c:\users\fadi\anaconda3\lib\site-packages (from yfinance) (2023.3.post1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\fadi\anaconda3\lib\site-packages (from yfinance) (2.3.8)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\fadi\anaconda3\lib\site-packages (from yfinance) (3.17.0)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\fadi\anaconda3\lib\site-packages (from yfinance) (4.12.2)
# Requirement already satisfied: html5lib>=1.1 in c:\users\fadi\anaconda3\lib\site-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\fadi\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: six>=1.9 in c:\users\fadi\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\fadi\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\fadi\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\fadi\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\fadi\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\fadi\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\fadi\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\fadi\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2023.7.22)
# Requirement already satisfied: matplotlib in c:\users\fadi\anaconda3\lib\site-packages (3.8.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\fadi\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\fadi\anaconda3\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\fadi\anaconda3\lib\site-packages (from matplotlib) (4.44.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\fadi\anaconda3\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in c:\users\fadi\anaconda3\lib\site-packages (from matplotlib) (1.26.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\fadi\anaconda3\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=8 in c:\users\fadi\anaconda3\lib\site-packages (from matplotlib) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\fadi\anaconda3\lib\site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\fadi\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\fadi\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
Apple = yf.download("AAPL", start = "2010-01-01")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
Apple
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-01-04    7.622500    7.660714    7.585000    7.643214    6.487533
# 2010-01-05    7.664286    7.699643    7.616071    7.656429    6.498749
# 2010-01-06    7.656429    7.686786    7.526786    7.534643    6.395380
# 2010-01-07    7.562500    7.571429    7.466071    7.520714    6.383555
# 2010-01-08    7.510714    7.571429    7.466429    7.570714    6.425995
# ...                ...         ...         ...         ...         ...
# 2023-11-03  174.240005  176.820007  173.350006  176.649994  176.649994
# 2023-11-06  176.380005  179.429993  176.210007  179.229996  179.229996
# 2023-11-07  179.179993  182.440002  178.970001  181.820007  181.820007
# 2023-11-08  182.350006  183.449997  181.589996  182.889999  182.889999
# 2023-11-09  182.960007  184.119995  181.809998  182.410004  182.410004
#
#                Volume
# Date
# 2010-01-04  493729600
# 2010-01-05  601904800
# 2010-01-06  552160000
# 2010-01-07  477131200
# 2010-01-08  447610800
# ...               ...
# 2023-11-03   79763700
# 2023-11-06   63841300
# 2023-11-07   70530000
# 2023-11-08   49340300
# 2023-11-09   53673900
#
# [3488 rows x 6 columns]

# %%
ticker=["SPY","AAPL","KO"]

# %%
stocks = yf.download(ticker, start = "2010-01-01")
# Out:
# [*********************100%%**********************]  3 of 3 completed

# %%
stocks
# Out:
#              Adj Close                              Close             \
#                   AAPL         KO         SPY        AAPL         KO
# Date
# 2010-01-04    6.487534  18.645309   87.483215    7.643214  28.520000
# 2010-01-05    6.498749  18.419760   87.714767    7.656429  28.174999
# 2010-01-06    6.395381  18.413219   87.776505    7.534643  28.165001
# 2010-01-07    6.383555  18.367458   88.147079    7.520714  28.094999
# 2010-01-08    6.425996  18.027504   88.440407    7.570714  27.575001
# ...                ...        ...         ...         ...        ...
# 2023-11-06  179.229996  56.970001  435.690002  179.229996  56.970001
# 2023-11-07  181.820007  57.180000  436.929993  181.820007  57.180000
# 2023-11-08  182.889999  57.090000  437.250000  182.889999  57.090000
# 2023-11-09  182.410004  56.660000  433.839996  182.410004  56.660000
# 2023-11-10         NaN  56.654999         NaN         NaN  56.654999
#
#                               High                                Low  \
#                    SPY        AAPL         KO         SPY        AAPL
# Date
# 2010-01-04  113.330002    7.660714  28.610001  113.389999    7.585000
# 2010-01-05  113.629997    7.699643  28.495001  113.680000    7.616071
# 2010-01-06  113.709999    7.686786  28.219999  113.989998    7.526786
# 2010-01-07  114.190002    7.571429  28.184999  114.330002    7.466071
# 2010-01-08  114.570000    7.571429  27.820000  114.620003    7.466429
# ...                ...         ...        ...         ...         ...
# 2023-11-06  435.690002  179.429993  57.279999  436.149994  176.210007
# 2023-11-07  436.929993  182.440002  57.400002  437.589996  178.970001
# 2023-11-08  437.250000  183.449997  57.470001  438.089996  181.589996
# 2023-11-09  433.839996  184.119995  57.139999  438.470001  181.809998
# 2023-11-10         NaN         NaN  56.924999         NaN         NaN
#
#                                          Open                         \
#                    KO         SPY        AAPL         KO         SPY
# Date
# 2010-01-04  28.450001  111.510002    7.622500  28.580000  112.370003
# 2010-01-05  28.070000  112.849998    7.664286  28.424999  113.260002
# 2010-01-06  27.990000  113.430000    7.656429  28.174999  113.519997
# 2010-01-07  27.875000  113.180000    7.562500  28.165001  113.500000
# 2010-01-08  27.375000  113.660004    7.510714  27.730000  113.889999
# ...               ...         ...         ...        ...         ...
# 2023-11-06  56.740002  433.679993  176.380005  56.779999  435.470001
# 2023-11-07  56.730000  434.510010  179.179993  56.919998  435.690002
# 2023-11-08  56.919998  434.869995  182.350006  57.320000  437.549988
# 2023-11-09  56.369999  433.399994  182.960007  57.029999  438.429993
# 2023-11-10  56.055000         NaN         NaN  56.869999         NaN
#
#                  Volume
#                    AAPL        KO          SPY
# Date
# 2010-01-04  493729600.0  13870400  118944600.0
# 2010-01-05  601904800.0  23172400  111579900.0
# 2010-01-06  552160000.0  19264600  116074400.0
# 2010-01-07  477131200.0  13234600  131091100.0
# 2010-01-08  447610800.0  28712400  126402800.0
# ...                 ...       ...          ...
# 2023-11-06   63841300.0  12673200   67831700.0
# 2023-11-07   70530000.0  10449300   64256100.0
# 2023-11-08   49340300.0  13744000   61746000.0
# 2023-11-09   53673900.0  12019500   83001900.0
# 2023-11-10          NaN   6346693          NaN
#
# [3489 rows x 18 columns]

# %%
stocks.head()
# Out:
#            Adj Close                           Close                         \
#                 AAPL         KO        SPY      AAPL         KO         SPY
# Date
# 2010-01-04  6.487534  18.645309  87.483215  7.643214  28.520000  113.330002
# 2010-01-05  6.498749  18.419760  87.714767  7.656429  28.174999  113.629997
# 2010-01-06  6.395381  18.413219  87.776505  7.534643  28.165001  113.709999
# 2010-01-07  6.383555  18.367458  88.147079  7.520714  28.094999  114.190002
# 2010-01-08  6.425996  18.027504  88.440407  7.570714  27.575001  114.570000
#
#                 High                              Low                         \
#                 AAPL         KO         SPY      AAPL         KO         SPY
# Date
# 2010-01-04  7.660714  28.610001  113.389999  7.585000  28.450001  111.510002
# 2010-01-05  7.699643  28.495001  113.680000  7.616071  28.070000  112.849998
# 2010-01-06  7.686786  28.219999  113.989998  7.526786  27.990000  113.430000
# 2010-01-07  7.571429  28.184999  114.330002  7.466071  27.875000  113.180000
# 2010-01-08  7.571429  27.820000  114.620003  7.466429  27.375000  113.660004
#
#                 Open                              Volume            \
#                 AAPL         KO         SPY         AAPL        KO
# Date
# 2010-01-04  7.622500  28.580000  112.370003  493729600.0  13870400
# 2010-01-05  7.664286  28.424999  113.260002  601904800.0  23172400
# 2010-01-06  7.656429  28.174999  113.519997  552160000.0  19264600
# 2010-01-07  7.562500  28.165001  113.500000  477131200.0  13234600
# 2010-01-08  7.510714  27.730000  113.889999  447610800.0  28712400
#
#
#                     SPY
# Date
# 2010-01-04  118944600.0
# 2010-01-05  111579900.0
# 2010-01-06  116074400.0
# 2010-01-07  131091100.0
# 2010-01-08  126402800.0

# %%
stocks.tail()
# Out:
#              Adj Close                              Close             \
#                   AAPL         KO         SPY        AAPL         KO
# Date
# 2023-11-06  179.229996  56.970001  435.690002  179.229996  56.970001
# 2023-11-07  181.820007  57.180000  436.929993  181.820007  57.180000
# 2023-11-08  182.889999  57.090000  437.250000  182.889999  57.090000
# 2023-11-09  182.410004  56.660000  433.839996  182.410004  56.660000
# 2023-11-10         NaN  56.654999         NaN         NaN  56.654999
#
#                               High                                Low  \
#                    SPY        AAPL         KO         SPY        AAPL
# Date
# 2023-11-06  435.690002  179.429993  57.279999  436.149994  176.210007
# 2023-11-07  436.929993  182.440002  57.400002  437.589996  178.970001
# 2023-11-08  437.250000  183.449997  57.470001  438.089996  181.589996
# 2023-11-09  433.839996  184.119995  57.139999  438.470001  181.809998
# 2023-11-10         NaN         NaN  56.924999         NaN         NaN
#
#                                          Open                         \
#                    KO         SPY        AAPL         KO         SPY
# Date
# 2023-11-06  56.740002  433.679993  176.380005  56.779999  435.470001
# 2023-11-07  56.730000  434.510010  179.179993  56.919998  435.690002
# 2023-11-08  56.919998  434.869995  182.350006  57.320000  437.549988
# 2023-11-09  56.369999  433.399994  182.960007  57.029999  438.429993
# 2023-11-10  56.055000         NaN         NaN  56.869999         NaN
#
#                 Volume
#                   AAPL        KO         SPY
# Date
# 2023-11-06  63841300.0  12673200  67831700.0
# 2023-11-07  70530000.0  10449300  64256100.0
# 2023-11-08  49340300.0  13744000  61746000.0
# 2023-11-09  53673900.0  12019500  83001900.0
# 2023-11-10         NaN   6346693         NaN

# %%
stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3489 entries, 2010-01-04 to 2023-11-10
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   (Adj Close, AAPL)  3488 non-null   float64
#  1   (Adj Close, KO)    3489 non-null   float64
#  2   (Adj Close, SPY)   3488 non-null   float64
#  3   (Close, AAPL)      3488 non-null   float64
#  4   (Close, KO)        3489 non-null   float64
#  5   (Close, SPY)       3488 non-null   float64
#  6   (High, AAPL)       3488 non-null   float64
#  7   (High, KO)         3489 non-null   float64
#  8   (High, SPY)        3488 non-null   float64
#  9   (Low, AAPL)        3488 non-null   float64
#  10  (Low, KO)          3489 non-null   float64
#  11  (Low, SPY)         3488 non-null   float64
#  12  (Open, AAPL)       3488 non-null   float64
#  13  (Open, KO)         3489 non-null   float64
#  14  (Open, SPY)        3488 non-null   float64
#  15  (Volume, AAPL)     3488 non-null   float64
#  16  (Volume, KO)       3489 non-null   int64
#  17  (Volume, SPY)      3488 non-null   float64
# dtypes: float64(17), int64(1)
# memory usage: 517.9 KB

# %%
stocks.to_csv("stocksYT.csv")

# %%
stocks = pd.read_csv("stocksYT.csv")

# %%
stocks
# Out:
#       Unnamed: 0           Adj Close         Adj Close.1         Adj Close.2  \
# 0            NaN                AAPL                  KO                 SPY
# 1           Date                 NaN                 NaN                 NaN
# 2     2010-01-04   6.487534046173096  18.645309448242188   87.48321533203125
# 3     2010-01-05   6.498748779296875   18.41975975036621   87.71476745605469
# 4     2010-01-06   6.395380973815918  18.413219451904297   87.77650451660156
# ...          ...                 ...                 ...                 ...
# 3486  2023-11-06  179.22999572753906  56.970001220703125  435.69000244140625
# 3487  2023-11-07  181.82000732421875   57.18000030517578  436.92999267578125
# 3488  2023-11-08  182.88999938964844   57.09000015258789              437.25
# 3489  2023-11-09  182.41000366210938   56.65999984741211   433.8399963378906
# 3490  2023-11-10                 NaN  56.654998779296875                 NaN
#
#                    Close             Close.1             Close.2  \
# 0                   AAPL                  KO                 SPY
# 1                    NaN                 NaN                 NaN
# 2      7.643214225769043  28.520000457763672  113.33000183105469
# 3      7.656428813934326  28.174999237060547  113.62999725341797
# 4      7.534643173217773  28.165000915527344  113.70999908447266
# ...                  ...                 ...                 ...
# 3486  179.22999572753906  56.970001220703125  435.69000244140625
# 3487  181.82000732421875   57.18000030517578  436.92999267578125
# 3488  182.88999938964844   57.09000015258789              437.25
# 3489  182.41000366210938   56.65999984741211   433.8399963378906
# 3490                 NaN  56.654998779296875                 NaN
#
#                     High              High.1              High.2  \
# 0                   AAPL                  KO                 SPY
# 1                    NaN                 NaN                 NaN
# 2      7.660714149475098  28.610000610351562  113.38999938964844
# 3      7.699643135070801    28.4950008392334  113.68000030517578
# 4       7.68678617477417  28.219999313354492  113.98999786376953
# ...                  ...                 ...                 ...
# 3486  179.42999267578125  57.279998779296875   436.1499938964844
# 3487  182.44000244140625  57.400001525878906   437.5899963378906
# 3488   183.4499969482422  57.470001220703125   438.0899963378906
# 3489   184.1199951171875   57.13999938964844   438.4700012207031
# 3490                 NaN   56.92499923706055                 NaN
#
#                      Low               Low.1               Low.2  \
# 0                   AAPL                  KO                 SPY
# 1                    NaN                 NaN                 NaN
# 2      7.585000038146973  28.450000762939453  111.51000213623047
# 3     7.6160712242126465   28.06999969482422   112.8499984741211
# 4      7.526785850524902  27.989999771118164  113.43000030517578
# ...                  ...                 ...                 ...
# 3486   176.2100067138672    56.7400016784668  433.67999267578125
# 3487  178.97000122070312   56.72999954223633    434.510009765625
# 3488  181.58999633789062   56.91999816894531   434.8699951171875
# 3489  181.80999755859375  56.369998931884766   433.3999938964844
# 3490                 NaN   56.05500030517578                 NaN
#
#                     Open              Open.1              Open.2       Volume  \
# 0                   AAPL                  KO                 SPY         AAPL
# 1                    NaN                 NaN                 NaN          NaN
# 2      7.622499942779541  28.579999923706055  112.37000274658203  493729600.0
# 3      7.664286136627197  28.424999237060547  113.26000213623047  601904800.0
# 4      7.656428813934326  28.174999237060547   113.5199966430664  552160000.0
# ...                  ...                 ...                 ...          ...
# 3486   176.3800048828125  56.779998779296875   435.4700012207031   63841300.0
# 3487  179.17999267578125   56.91999816894531  435.69000244140625   70530000.0
# 3488  182.35000610351562   57.31999969482422  437.54998779296875   49340300.0
# 3489   182.9600067138672  57.029998779296875  438.42999267578125   53673900.0
# 3490                 NaN  56.869998931884766                 NaN          NaN
#
#       Volume.1     Volume.2
# 0           KO          SPY
# 1          NaN          NaN
# 2     13870400  118944600.0
# 3     23172400  111579900.0
# 4     19264600  116074400.0
# ...        ...          ...
# 3486  12673200   67831700.0
# 3487  10449300   64256100.0
# 3488  13744000   61746000.0
# 3489  12019500   83001900.0
# 3490   6346693          NaN
#
# [3491 rows x 19 columns]

# %%
stocks = pd.read_csv("stocksYT.csv",header=[0,1])
stocks
# Out:
#      Unnamed: 0_level_0   Adj Close                              Close  \
#      Unnamed: 0_level_1        AAPL         KO         SPY        AAPL
# 0                  Date         NaN        NaN         NaN         NaN
# 1            2010-01-04    6.487534  18.645309   87.483215    7.643214
# 2            2010-01-05    6.498749  18.419760   87.714767    7.656429
# 3            2010-01-06    6.395381  18.413219   87.776505    7.534643
# 4            2010-01-07    6.383555  18.367458   88.147079    7.520714
# ...                 ...         ...        ...         ...         ...
# 3485         2023-11-06  179.229996  56.970001  435.690002  179.229996
# 3486         2023-11-07  181.820007  57.180000  436.929993  181.820007
# 3487         2023-11-08  182.889999  57.090000  437.250000  182.889999
# 3488         2023-11-09  182.410004  56.660000  433.839996  182.410004
# 3489         2023-11-10         NaN  56.654999         NaN         NaN
#
#                                    High                                Low  \
#              KO         SPY        AAPL         KO         SPY        AAPL
# 0           NaN         NaN         NaN        NaN         NaN         NaN
# 1     28.520000  113.330002    7.660714  28.610001  113.389999    7.585000
# 2     28.174999  113.629997    7.699643  28.495001  113.680000    7.616071
# 3     28.165001  113.709999    7.686786  28.219999  113.989998    7.526786
# 4     28.094999  114.190002    7.571429  28.184999  114.330002    7.466071
# ...         ...         ...         ...        ...         ...         ...
# 3485  56.970001  435.690002  179.429993  57.279999  436.149994  176.210007
# 3486  57.180000  436.929993  182.440002  57.400002  437.589996  178.970001
# 3487  57.090000  437.250000  183.449997  57.470001  438.089996  181.589996
# 3488  56.660000  433.839996  184.119995  57.139999  438.470001  181.809998
# 3489  56.654999         NaN         NaN  56.924999         NaN         NaN
#
#                                    Open                              Volume  \
#              KO         SPY        AAPL         KO         SPY         AAPL
# 0           NaN         NaN         NaN        NaN         NaN          NaN
# 1     28.450001  111.510002    7.622500  28.580000  112.370003  493729600.0
# 2     28.070000  112.849998    7.664286  28.424999  113.260002  601904800.0
# 3     27.990000  113.430000    7.656429  28.174999  113.519997  552160000.0
# 4     27.875000  113.180000    7.562500  28.165001  113.500000  477131200.0
# ...         ...         ...         ...        ...         ...          ...
# 3485  56.740002  433.679993  176.380005  56.779999  435.470001   63841300.0
# 3486  56.730000  434.510010  179.179993  56.919998  435.690002   70530000.0
# 3487  56.919998  434.869995  182.350006  57.320000  437.549988   49340300.0
# 3488  56.369999  433.399994  182.960007  57.029999  438.429993   53673900.0
# 3489  56.055000         NaN         NaN  56.869999         NaN          NaN
#
#
#               KO          SPY
# 0            NaN          NaN
# 1     13870400.0  118944600.0
# 2     23172400.0  111579900.0
# 3     19264600.0  116074400.0
# 4     13234600.0  131091100.0
# ...          ...          ...
# 3485  12673200.0   67831700.0
# 3486  10449300.0   64256100.0
# 3487  13744000.0   61746000.0
# 3488  12019500.0   83001900.0
# 3489   6346693.0          NaN
#
# [3490 rows x 19 columns]

# %%
stocks = pd.read_csv("stocksYT.csv",header=[0,1],index_col=[0])
stocks
# Out:
#              Adj Close                              Close             \
#                   AAPL         KO         SPY        AAPL         KO
# Date
# 2010-01-04    6.487534  18.645309   87.483215    7.643214  28.520000
# 2010-01-05    6.498749  18.419760   87.714767    7.656429  28.174999
# 2010-01-06    6.395381  18.413219   87.776505    7.534643  28.165001
# 2010-01-07    6.383555  18.367458   88.147079    7.520714  28.094999
# 2010-01-08    6.425996  18.027504   88.440407    7.570714  27.575001
# ...                ...        ...         ...         ...        ...
# 2023-11-06  179.229996  56.970001  435.690002  179.229996  56.970001
# 2023-11-07  181.820007  57.180000  436.929993  181.820007  57.180000
# 2023-11-08  182.889999  57.090000  437.250000  182.889999  57.090000
# 2023-11-09  182.410004  56.660000  433.839996  182.410004  56.660000
# 2023-11-10         NaN  56.654999         NaN         NaN  56.654999
#
#                               High                                Low  \
#                    SPY        AAPL         KO         SPY        AAPL
# Date
# 2010-01-04  113.330002    7.660714  28.610001  113.389999    7.585000
# 2010-01-05  113.629997    7.699643  28.495001  113.680000    7.616071
# 2010-01-06  113.709999    7.686786  28.219999  113.989998    7.526786
# 2010-01-07  114.190002    7.571429  28.184999  114.330002    7.466071
# 2010-01-08  114.570000    7.571429  27.820000  114.620003    7.466429
# ...                ...         ...        ...         ...         ...
# 2023-11-06  435.690002  179.429993  57.279999  436.149994  176.210007
# 2023-11-07  436.929993  182.440002  57.400002  437.589996  178.970001
# 2023-11-08  437.250000  183.449997  57.470001  438.089996  181.589996
# 2023-11-09  433.839996  184.119995  57.139999  438.470001  181.809998
# 2023-11-10         NaN         NaN  56.924999         NaN         NaN
#
#                                          Open                         \
#                    KO         SPY        AAPL         KO         SPY
# Date
# 2010-01-04  28.450001  111.510002    7.622500  28.580000  112.370003
# 2010-01-05  28.070000  112.849998    7.664286  28.424999  113.260002
# 2010-01-06  27.990000  113.430000    7.656429  28.174999  113.519997
# 2010-01-07  27.875000  113.180000    7.562500  28.165001  113.500000
# 2010-01-08  27.375000  113.660004    7.510714  27.730000  113.889999
# ...               ...         ...         ...        ...         ...
# 2023-11-06  56.740002  433.679993  176.380005  56.779999  435.470001
# 2023-11-07  56.730000  434.510010  179.179993  56.919998  435.690002
# 2023-11-08  56.919998  434.869995  182.350006  57.320000  437.549988
# 2023-11-09  56.369999  433.399994  182.960007  57.029999  438.429993
# 2023-11-10  56.055000         NaN         NaN  56.869999         NaN
#
#                  Volume
#                    AAPL        KO          SPY
# Date
# 2010-01-04  493729600.0  13870400  118944600.0
# 2010-01-05  601904800.0  23172400  111579900.0
# 2010-01-06  552160000.0  19264600  116074400.0
# 2010-01-07  477131200.0  13234600  131091100.0
# 2010-01-08  447610800.0  28712400  126402800.0
# ...                 ...       ...          ...
# 2023-11-06   63841300.0  12673200   67831700.0
# 2023-11-07   70530000.0  10449300   64256100.0
# 2023-11-08   49340300.0  13744000   61746000.0
# 2023-11-09   53673900.0  12019500   83001900.0
# 2023-11-10          NaN   6346693          NaN
#
# [3489 rows x 18 columns]

# %%
stocks = pd.read_csv("stocksYT.csv",header=[0,1],index_col=[0], parse_dates=[0])
stocks
# Out:
#              Adj Close                              Close             \
#                   AAPL         KO         SPY        AAPL         KO
# Date
# 2010-01-04    6.487534  18.645309   87.483215    7.643214  28.520000
# 2010-01-05    6.498749  18.419760   87.714767    7.656429  28.174999
# 2010-01-06    6.395381  18.413219   87.776505    7.534643  28.165001
# 2010-01-07    6.383555  18.367458   88.147079    7.520714  28.094999
# 2010-01-08    6.425996  18.027504   88.440407    7.570714  27.575001
# ...                ...        ...         ...         ...        ...
# 2023-11-06  179.229996  56.970001  435.690002  179.229996  56.970001
# 2023-11-07  181.820007  57.180000  436.929993  181.820007  57.180000
# 2023-11-08  182.889999  57.090000  437.250000  182.889999  57.090000
# 2023-11-09  182.410004  56.660000  433.839996  182.410004  56.660000
# 2023-11-10         NaN  56.654999         NaN         NaN  56.654999
#
#                               High                                Low  \
#                    SPY        AAPL         KO         SPY        AAPL
# Date
# 2010-01-04  113.330002    7.660714  28.610001  113.389999    7.585000
# 2010-01-05  113.629997    7.699643  28.495001  113.680000    7.616071
# 2010-01-06  113.709999    7.686786  28.219999  113.989998    7.526786
# 2010-01-07  114.190002    7.571429  28.184999  114.330002    7.466071
# 2010-01-08  114.570000    7.571429  27.820000  114.620003    7.466429
# ...                ...         ...        ...         ...         ...
# 2023-11-06  435.690002  179.429993  57.279999  436.149994  176.210007
# 2023-11-07  436.929993  182.440002  57.400002  437.589996  178.970001
# 2023-11-08  437.250000  183.449997  57.470001  438.089996  181.589996
# 2023-11-09  433.839996  184.119995  57.139999  438.470001  181.809998
# 2023-11-10         NaN         NaN  56.924999         NaN         NaN
#
#                                          Open                         \
#                    KO         SPY        AAPL         KO         SPY
# Date
# 2010-01-04  28.450001  111.510002    7.622500  28.580000  112.370003
# 2010-01-05  28.070000  112.849998    7.664286  28.424999  113.260002
# 2010-01-06  27.990000  113.430000    7.656429  28.174999  113.519997
# 2010-01-07  27.875000  113.180000    7.562500  28.165001  113.500000
# 2010-01-08  27.375000  113.660004    7.510714  27.730000  113.889999
# ...               ...         ...         ...        ...         ...
# 2023-11-06  56.740002  433.679993  176.380005  56.779999  435.470001
# 2023-11-07  56.730000  434.510010  179.179993  56.919998  435.690002
# 2023-11-08  56.919998  434.869995  182.350006  57.320000  437.549988
# 2023-11-09  56.369999  433.399994  182.960007  57.029999  438.429993
# 2023-11-10  56.055000         NaN         NaN  56.869999         NaN
#
#                  Volume
#                    AAPL        KO          SPY
# Date
# 2010-01-04  493729600.0  13870400  118944600.0
# 2010-01-05  601904800.0  23172400  111579900.0
# 2010-01-06  552160000.0  19264600  116074400.0
# 2010-01-07  477131200.0  13234600  131091100.0
# 2010-01-08  447610800.0  28712400  126402800.0
# ...                 ...       ...          ...
# 2023-11-06   63841300.0  12673200   67831700.0
# 2023-11-07   70530000.0  10449300   64256100.0
# 2023-11-08   49340300.0  13744000   61746000.0
# 2023-11-09   53673900.0  12019500   83001900.0
# 2023-11-10          NaN   6346693          NaN
#
# [3489 rows x 18 columns]

# %%
stocks.columns
# Out:
# MultiIndex([('Adj Close', 'AAPL'),
#             ('Adj Close',   'KO'),
#             ('Adj Close',  'SPY'),
#             (    'Close', 'AAPL'),
#             (    'Close',   'KO'),
#             (    'Close',  'SPY'),
#             (     'High', 'AAPL'),
#             (     'High',   'KO'),
#             (     'High',  'SPY'),
#             (      'Low', 'AAPL'),
#             (      'Low',   'KO'),
#             (      'Low',  'SPY'),
#             (     'Open', 'AAPL'),
#             (     'Open',   'KO'),
#             (     'Open',  'SPY'),
#             (   'Volume', 'AAPL'),
#             (   'Volume',   'KO'),
#             (   'Volume',  'SPY')],
#            )

# %%
#convert mult index to one tuple
stocks.columns=stocks.columns.to_flat_index()

# %%
stocks.columns
# Out:
# Index([('Adj Close', 'AAPL'),   ('Adj Close', 'KO'),  ('Adj Close', 'SPY'),
#            ('Close', 'AAPL'),       ('Close', 'KO'),      ('Close', 'SPY'),
#             ('High', 'AAPL'),        ('High', 'KO'),       ('High', 'SPY'),
#              ('Low', 'AAPL'),         ('Low', 'KO'),        ('Low', 'SPY'),
#             ('Open', 'AAPL'),        ('Open', 'KO'),       ('Open', 'SPY'),
#           ('Volume', 'AAPL'),      ('Volume', 'KO'),     ('Volume', 'SPY')],
#       dtype='object')

# %%
stocks
# Out:
#             (Adj Close, AAPL)  (Adj Close, KO)  (Adj Close, SPY)  \
# Date
# 2010-01-04           6.487534        18.645309         87.483215
# 2010-01-05           6.498749        18.419760         87.714767
# 2010-01-06           6.395381        18.413219         87.776505
# 2010-01-07           6.383555        18.367458         88.147079
# 2010-01-08           6.425996        18.027504         88.440407
# ...                       ...              ...               ...
# 2023-11-06         179.229996        56.970001        435.690002
# 2023-11-07         181.820007        57.180000        436.929993
# 2023-11-08         182.889999        57.090000        437.250000
# 2023-11-09         182.410004        56.660000        433.839996
# 2023-11-10                NaN        56.654999               NaN
#
#             (Close, AAPL)  (Close, KO)  (Close, SPY)  (High, AAPL)  \
# Date
# 2010-01-04       7.643214    28.520000    113.330002      7.660714
# 2010-01-05       7.656429    28.174999    113.629997      7.699643
# 2010-01-06       7.534643    28.165001    113.709999      7.686786
# 2010-01-07       7.520714    28.094999    114.190002      7.571429
# 2010-01-08       7.570714    27.575001    114.570000      7.571429
# ...                   ...          ...           ...           ...
# 2023-11-06     179.229996    56.970001    435.690002    179.429993
# 2023-11-07     181.820007    57.180000    436.929993    182.440002
# 2023-11-08     182.889999    57.090000    437.250000    183.449997
# 2023-11-09     182.410004    56.660000    433.839996    184.119995
# 2023-11-10            NaN    56.654999           NaN           NaN
#
#             (High, KO)  (High, SPY)  (Low, AAPL)  (Low, KO)  (Low, SPY)  \
# Date
# 2010-01-04   28.610001   113.389999     7.585000  28.450001  111.510002
# 2010-01-05   28.495001   113.680000     7.616071  28.070000  112.849998
# 2010-01-06   28.219999   113.989998     7.526786  27.990000  113.430000
# 2010-01-07   28.184999   114.330002     7.466071  27.875000  113.180000
# 2010-01-08   27.820000   114.620003     7.466429  27.375000  113.660004
# ...                ...          ...          ...        ...         ...
# 2023-11-06   57.279999   436.149994   176.210007  56.740002  433.679993
# 2023-11-07   57.400002   437.589996   178.970001  56.730000  434.510010
# 2023-11-08   57.470001   438.089996   181.589996  56.919998  434.869995
# 2023-11-09   57.139999   438.470001   181.809998  56.369999  433.399994
# 2023-11-10   56.924999          NaN          NaN  56.055000         NaN
#
#             (Open, AAPL)  (Open, KO)  (Open, SPY)  (Volume, AAPL)  \
# Date
# 2010-01-04      7.622500   28.580000   112.370003     493729600.0
# 2010-01-05      7.664286   28.424999   113.260002     601904800.0
# 2010-01-06      7.656429   28.174999   113.519997     552160000.0
# 2010-01-07      7.562500   28.165001   113.500000     477131200.0
# 2010-01-08      7.510714   27.730000   113.889999     447610800.0
# ...                  ...         ...          ...             ...
# 2023-11-06    176.380005   56.779999   435.470001      63841300.0
# 2023-11-07    179.179993   56.919998   435.690002      70530000.0
# 2023-11-08    182.350006   57.320000   437.549988      49340300.0
# 2023-11-09    182.960007   57.029999   438.429993      53673900.0
# 2023-11-10           NaN   56.869999          NaN             NaN
#
#             (Volume, KO)  (Volume, SPY)
# Date
# 2010-01-04      13870400    118944600.0
# 2010-01-05      23172400    111579900.0
# 2010-01-06      19264600    116074400.0
# 2010-01-07      13234600    131091100.0
# 2010-01-08      28712400    126402800.0
# ...                  ...            ...
# 2023-11-06      12673200     67831700.0
# 2023-11-07      10449300     64256100.0
# 2023-11-08      13744000     61746000.0
# 2023-11-09      12019500     83001900.0
# 2023-11-10       6346693            NaN
#
# [3489 rows x 18 columns]

# %%
stocks.columns=pd.MultiIndex.from_tuples(stocks.columns)
stocks
# Out:
#              Adj Close                              Close             \
#                   AAPL         KO         SPY        AAPL         KO
# Date
# 2010-01-04    6.487534  18.645309   87.483215    7.643214  28.520000
# 2010-01-05    6.498749  18.419760   87.714767    7.656429  28.174999
# 2010-01-06    6.395381  18.413219   87.776505    7.534643  28.165001
# 2010-01-07    6.383555  18.367458   88.147079    7.520714  28.094999
# 2010-01-08    6.425996  18.027504   88.440407    7.570714  27.575001
# ...                ...        ...         ...         ...        ...
# 2023-11-06  179.229996  56.970001  435.690002  179.229996  56.970001
# 2023-11-07  181.820007  57.180000  436.929993  181.820007  57.180000
# 2023-11-08  182.889999  57.090000  437.250000  182.889999  57.090000
# 2023-11-09  182.410004  56.660000  433.839996  182.410004  56.660000
# 2023-11-10         NaN  56.654999         NaN         NaN  56.654999
#
#                               High                                Low  \
#                    SPY        AAPL         KO         SPY        AAPL
# Date
# 2010-01-04  113.330002    7.660714  28.610001  113.389999    7.585000
# 2010-01-05  113.629997    7.699643  28.495001  113.680000    7.616071
# 2010-01-06  113.709999    7.686786  28.219999  113.989998    7.526786
# 2010-01-07  114.190002    7.571429  28.184999  114.330002    7.466071
# 2010-01-08  114.570000    7.571429  27.820000  114.620003    7.466429
# ...                ...         ...        ...         ...         ...
# 2023-11-06  435.690002  179.429993  57.279999  436.149994  176.210007
# 2023-11-07  436.929993  182.440002  57.400002  437.589996  178.970001
# 2023-11-08  437.250000  183.449997  57.470001  438.089996  181.589996
# 2023-11-09  433.839996  184.119995  57.139999  438.470001  181.809998
# 2023-11-10         NaN         NaN  56.924999         NaN         NaN
#
#                                          Open                         \
#                    KO         SPY        AAPL         KO         SPY
# Date
# 2010-01-04  28.450001  111.510002    7.622500  28.580000  112.370003
# 2010-01-05  28.070000  112.849998    7.664286  28.424999  113.260002
# 2010-01-06  27.990000  113.430000    7.656429  28.174999  113.519997
# 2010-01-07  27.875000  113.180000    7.562500  28.165001  113.500000
# 2010-01-08  27.375000  113.660004    7.510714  27.730000  113.889999
# ...               ...         ...         ...        ...         ...
# 2023-11-06  56.740002  433.679993  176.380005  56.779999  435.470001
# 2023-11-07  56.730000  434.510010  179.179993  56.919998  435.690002
# 2023-11-08  56.919998  434.869995  182.350006  57.320000  437.549988
# 2023-11-09  56.369999  433.399994  182.960007  57.029999  438.429993
# 2023-11-10  56.055000         NaN         NaN  56.869999         NaN
#
#                  Volume
#                    AAPL        KO          SPY
# Date
# 2010-01-04  493729600.0  13870400  118944600.0
# 2010-01-05  601904800.0  23172400  111579900.0
# 2010-01-06  552160000.0  19264600  116074400.0
# 2010-01-07  477131200.0  13234600  131091100.0
# 2010-01-08  447610800.0  28712400  126402800.0
# ...                 ...       ...          ...
# 2023-11-06   63841300.0  12673200   67831700.0
# 2023-11-07   70530000.0  10449300   64256100.0
# 2023-11-08   49340300.0  13744000   61746000.0
# 2023-11-09   53673900.0  12019500   83001900.0
# 2023-11-10          NaN   6346693          NaN
#
# [3489 rows x 18 columns]

# %%
stocks.columns
# Out:
# MultiIndex([('Adj Close', 'AAPL'),
#             ('Adj Close',   'KO'),
#             ('Adj Close',  'SPY'),
#             (    'Close', 'AAPL'),
#             (    'Close',   'KO'),
#             (    'Close',  'SPY'),
#             (     'High', 'AAPL'),
#             (     'High',   'KO'),
#             (     'High',  'SPY'),
#             (      'Low', 'AAPL'),
#             (      'Low',   'KO'),
#             (      'Low',  'SPY'),
#             (     'Open', 'AAPL'),
#             (     'Open',   'KO'),
#             (     'Open',  'SPY'),
#             (   'Volume', 'AAPL'),
#             (   'Volume',   'KO'),
#             (   'Volume',  'SPY')],
#            )

# %%
stocks.describe()
# Out:
#          Adj Close                                  Close               \
#               AAPL           KO          SPY         AAPL           KO
# count  3488.000000  3489.000000  3488.000000  3488.000000  3489.000000
# mean     56.685932    37.369911   229.662947    58.636774    44.874726
# std      54.591312    12.309887   111.825966    54.145023     9.436448
# min       5.821835    16.504198    79.593353     6.858929    25.014999
# 25%      17.005881    28.288887   135.982792    19.491607    38.799999
# 50%      28.937183    34.935902   196.239647    32.129999    43.470001
# 75%      79.102604    46.472923   304.419006    80.920624    51.820000
# max     196.185074    63.318047   464.923370   196.449997    66.209999
#
#                            High                                    Low  \
#                SPY         AAPL           KO          SPY         AAPL
# count  3488.000000  3488.000000  3489.000000  3488.000000  3488.000000
# mean    251.231660    59.235388    45.170013   252.581101    57.984111
# std     105.132448    54.724604     9.516679   105.784619    53.506066
# min     102.199997     7.000000    25.150000   103.419998     6.794643
# 25%     164.427502    19.710804    39.040001   165.372505    19.291786
# 50%     221.610001    32.323750    43.730000   221.780006    31.821250
# 75%     321.852501    81.218752    52.139999   323.410004    80.016251
# max     477.709991   198.229996    67.199997   479.980011   195.279999
#
#                                         Open                            \
#                 KO          SPY         AAPL           KO          SPY
# count  3489.000000  3488.000000  3488.000000  3489.000000  3488.000000
# mean     44.568214   249.682377    58.594305    44.874134   251.192147
# std       9.358549   104.415351    54.086186     9.441673   105.127415
# min      24.735001   101.129997     6.870357    25.110001   103.110001
# 25%      38.580002   163.394997    19.566160    38.840000   164.437500
# 50%      43.189999   220.540001    32.084999    43.439999   221.370003
# 75%      51.470001   320.407486    80.846876    51.900002   321.599998
# max      65.720001   476.059998   196.240005    67.000000   479.220001
#
#              Volume
#                AAPL            KO           SPY
# count  3.488000e+03  3.489000e+03  3.488000e+03
# mean   2.441546e+08  1.506237e+07  1.160869e+08
# std    2.207031e+08  6.680741e+06  6.988007e+07
# min    3.145820e+07  2.996300e+06  2.027000e+07
# 25%    9.423070e+07  1.084420e+07  6.966338e+07
# 50%    1.543670e+08  1.360920e+07  9.616630e+07
# 75%    3.310335e+08  1.743760e+07  1.416444e+08
# max    1.880998e+09  9.896750e+07  7.178287e+08

# %%
close=stocks.loc[:,"Close"].copy()

# %%
close
# Out:
#                   AAPL         KO         SPY
# Date
# 2010-01-04    7.643214  28.520000  113.330002
# 2010-01-05    7.656429  28.174999  113.629997
# 2010-01-06    7.534643  28.165001  113.709999
# 2010-01-07    7.520714  28.094999  114.190002
# 2010-01-08    7.570714  27.575001  114.570000
# ...                ...        ...         ...
# 2023-11-06  179.229996  56.970001  435.690002
# 2023-11-07  181.820007  57.180000  436.929993
# 2023-11-08  182.889999  57.090000  437.250000
# 2023-11-09  182.410004  56.660000  433.839996
# 2023-11-10         NaN  56.654999         NaN
#
# [3489 rows x 3 columns]

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\fadi\anaconda3\lib\site-packages (0.13.0)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\fadi\anaconda3\lib\site-packages (from seaborn) (1.26.1)
# Requirement already satisfied: pandas>=1.2 in c:\users\fadi\anaconda3\lib\site-packages (from seaborn) (2.1.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.3 in c:\users\fadi\anaconda3\lib\site-packages (from seaborn) (3.8.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\fadi\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\fadi\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\fadi\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (4.44.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\fadi\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\fadi\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (23.1)
# Requirement already satisfied: pillow>=8 in c:\users\fadi\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\fadi\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\fadi\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\fadi\anaconda3\lib\site-packages (from pandas>=1.2->seaborn) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\fadi\anaconda3\lib\site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\fadi\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.3->seaborn) (1.16.0)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use("seaborn-v0_8")

# %%
close.plot(figsize=(15,8),fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %%
close.iloc[0,0]
# Out:
# 7.643214225769043

# %%
close.AAPL
# Out:
# Date
# 2010-01-04      7.643214
# 2010-01-05      7.656429
# 2010-01-06      7.534643
# 2010-01-07      7.520714
# 2010-01-08      7.570714
#                  ...
# 2023-11-06    179.229996
# 2023-11-07    181.820007
# 2023-11-08    182.889999
# 2023-11-09    182.410004
# 2023-11-10           NaN
# Name: AAPL, Length: 3489, dtype: float64

# %%
close.AAPL.div(close.iloc[0,0])
# Out:
# Date
# 2010-01-04     1.000000
# 2010-01-05     1.001729
# 2010-01-06     0.985795
# 2010-01-07     0.983973
# 2010-01-08     0.990514
#                 ...
# 2023-11-06    23.449558
# 2023-11-07    23.788422
# 2023-11-08    23.928415
# 2023-11-09    23.865614
# 2023-11-10          NaN
# Name: AAPL, Length: 3489, dtype: float64

# %%
close.AAPL.div(close.iloc[0,0]).mul(100)
# Out:
# Date
# 2010-01-04     100.000000
# 2010-01-05     100.172893
# 2010-01-06      98.579511
# 2010-01-07      98.397266
# 2010-01-08      99.051443
#                  ...
# 2023-11-06    2344.955806
# 2023-11-07    2378.842225
# 2023-11-08    2392.841467
# 2023-11-09    2386.561442
# 2023-11-10            NaN
# Name: AAPL, Length: 3489, dtype: float64

# %%
close.iloc[0]
# Out:
# AAPL      7.643214
# KO       28.520000
# SPY     113.330002
# Name: 2010-01-04 00:00:00, dtype: float64

# %%
close.div(close.iloc[0]).mul(100)
# Out:
#                    AAPL          KO         SPY
# Date
# 2010-01-04   100.000000  100.000000  100.000000
# 2010-01-05   100.172893   98.790318  100.264710
# 2010-01-06    98.579511   98.755261  100.335302
# 2010-01-07    98.397266   98.509814  100.758846
# 2010-01-08    99.051443   96.686537  101.094148
# ...                 ...         ...         ...
# 2023-11-06  2344.955806  199.754559  384.443656
# 2023-11-07  2378.842225  200.490881  385.537797
# 2023-11-08  2392.841467  200.175313  385.820165
# 2023-11-09  2386.561442  198.667598  382.811250
# 2023-11-10          NaN  198.650063         NaN
#
# [3489 rows x 3 columns]

# %%
normclose=close.div(close.iloc[0]).mul(100)

# %%
normclose.plot(figsize=(15,8),fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %%
aapl= close.AAPL.copy().to_frame()

# %%
aapl
# Out:
#                   AAPL
# Date
# 2010-01-04    7.643214
# 2010-01-05    7.656429
# 2010-01-06    7.534643
# 2010-01-07    7.520714
# 2010-01-08    7.570714
# ...                ...
# 2023-11-06  179.229996
# 2023-11-07  181.820007
# 2023-11-08  182.889999
# 2023-11-09  182.410004
# 2023-11-10         NaN
#
# [3489 rows x 1 columns]

# %%
aapl.shift(periods=1)
# Out:
#                   AAPL
# Date
# 2010-01-04         NaN
# 2010-01-05    7.643214
# 2010-01-06    7.656429
# 2010-01-07    7.534643
# 2010-01-08    7.520714
# ...                ...
# 2023-11-06  176.649994
# 2023-11-07  179.229996
# 2023-11-08  181.820007
# 2023-11-09  182.889999
# 2023-11-10  182.410004
#
# [3489 rows x 1 columns]

# %%
aapl["lag1"]=aapl.shift(periods=1)

# %%
aapl
# Out:
#                   AAPL        lag1
# Date
# 2010-01-04    7.643214         NaN
# 2010-01-05    7.656429    7.643214
# 2010-01-06    7.534643    7.656429
# 2010-01-07    7.520714    7.534643
# 2010-01-08    7.570714    7.520714
# ...                ...         ...
# 2023-11-06  179.229996  176.649994
# 2023-11-07  181.820007  179.229996
# 2023-11-08  182.889999  181.820007
# 2023-11-09  182.410004  182.889999
# 2023-11-10         NaN  182.410004
#
# [3489 rows x 2 columns]

# %%
aapl["Diff"]=aapl.AAPL.sub(aapl.lag1)

# %%
aapl
# Out:
#                   AAPL        lag1      Diff
# Date
# 2010-01-04    7.643214         NaN       NaN
# 2010-01-05    7.656429    7.643214  0.013215
# 2010-01-06    7.534643    7.656429 -0.121786
# 2010-01-07    7.520714    7.534643 -0.013929
# 2010-01-08    7.570714    7.520714  0.050000
# ...                ...         ...       ...
# 2023-11-06  179.229996  176.649994  2.580002
# 2023-11-07  181.820007  179.229996  2.590012
# 2023-11-08  182.889999  181.820007  1.069992
# 2023-11-09  182.410004  182.889999 -0.479996
# 2023-11-10         NaN  182.410004       NaN
#
# [3489 rows x 3 columns]

# %%
aapl["% Change"]=aapl.AAPL.div(aapl.lag1).sub(1).mul(100)

# %%
aapl
# Out:
#                   AAPL        lag1      Diff  % Change
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN
# 2010-01-05    7.656429    7.643214  0.013215  0.172893
# 2010-01-06    7.534643    7.656429 -0.121786 -1.590632
# 2010-01-07    7.520714    7.534643 -0.013929 -0.184871
# 2010-01-08    7.570714    7.520714  0.050000  0.664833
# ...                ...         ...       ...       ...
# 2023-11-06  179.229996  176.649994  2.580002  1.460516
# 2023-11-07  181.820007  179.229996  2.590012  1.445077
# 2023-11-08  182.889999  181.820007  1.069992  0.588490
# 2023-11-09  182.410004  182.889999 -0.479996 -0.262451
# 2023-11-10         NaN  182.410004       NaN       NaN
#
# [3489 rows x 4 columns]

# %%
aapl["% Change"]=aapl.Diff.div(aapl.lag1).mul(100)
aapl
# Out:
#                   AAPL        lag1      Diff  % Change
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN
# 2010-01-05    7.656429    7.643214  0.013215  0.172893
# 2010-01-06    7.534643    7.656429 -0.121786 -1.590632
# 2010-01-07    7.520714    7.534643 -0.013929 -0.184871
# 2010-01-08    7.570714    7.520714  0.050000  0.664833
# ...                ...         ...       ...       ...
# 2023-11-06  179.229996  176.649994  2.580002  1.460516
# 2023-11-07  181.820007  179.229996  2.590012  1.445077
# 2023-11-08  182.889999  181.820007  1.069992  0.588490
# 2023-11-09  182.410004  182.889999 -0.479996 -0.262451
# 2023-11-10         NaN  182.410004       NaN       NaN
#
# [3489 rows x 4 columns]

# %%
aapl["Diff2"]=aapl.AAPL.diff(periods=1)
aapl
# Out:
#                   AAPL        lag1      Diff  % Change     Diff2
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN       NaN
# 2010-01-05    7.656429    7.643214  0.013215  0.172893  0.013215
# 2010-01-06    7.534643    7.656429 -0.121786 -1.590632 -0.121786
# 2010-01-07    7.520714    7.534643 -0.013929 -0.184871 -0.013929
# 2010-01-08    7.570714    7.520714  0.050000  0.664833  0.050000
# ...                ...         ...       ...       ...       ...
# 2023-11-06  179.229996  176.649994  2.580002  1.460516  2.580002
# 2023-11-07  181.820007  179.229996  2.590012  1.445077  2.590012
# 2023-11-08  182.889999  181.820007  1.069992  0.588490  1.069992
# 2023-11-09  182.410004  182.889999 -0.479996 -0.262451 -0.479996
# 2023-11-10         NaN  182.410004       NaN       NaN       NaN
#
# [3489 rows x 5 columns]

# %%
aapl["% Change 2"]=aapl.AAPL.pct_change(periods=1).mul(100)
# Out:
# C:\Users\Fadi\AppData\Local\Temp\ipykernel_25916\1695705565.py:1: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   aapl["% Change 2"]=aapl.AAPL.pct_change(periods=1).mul(100)

# %%
aapl
# Out:
#                   AAPL        lag1      Diff  % Change     Diff2  % Change 2
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN       NaN         NaN
# 2010-01-05    7.656429    7.643214  0.013215  0.172893  0.013215    0.172893
# 2010-01-06    7.534643    7.656429 -0.121786 -1.590632 -0.121786   -1.590632
# 2010-01-07    7.520714    7.534643 -0.013929 -0.184871 -0.013929   -0.184871
# 2010-01-08    7.570714    7.520714  0.050000  0.664833  0.050000    0.664833
# ...                ...         ...       ...       ...       ...         ...
# 2023-11-06  179.229996  176.649994  2.580002  1.460516  2.580002    1.460516
# 2023-11-07  181.820007  179.229996  2.590012  1.445077  2.590012    1.445077
# 2023-11-08  182.889999  181.820007  1.069992  0.588490  1.069992    0.588490
# 2023-11-09  182.410004  182.889999 -0.479996 -0.262451 -0.479996   -0.262451
# 2023-11-10         NaN  182.410004       NaN       NaN       NaN    0.000000
#
# [3489 rows x 6 columns]

# %%
del aapl["% Change"]

# %%
aapl
# Out:
#                   AAPL        lag1      Diff     Diff2  % Change 2
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN         NaN
# 2010-01-05    7.656429    7.643214  0.013215  0.013215    0.172893
# 2010-01-06    7.534643    7.656429 -0.121786 -0.121786   -1.590632
# 2010-01-07    7.520714    7.534643 -0.013929 -0.013929   -0.184871
# 2010-01-08    7.570714    7.520714  0.050000  0.050000    0.664833
# ...                ...         ...       ...       ...         ...
# 2023-11-06  179.229996  176.649994  2.580002  2.580002    1.460516
# 2023-11-07  181.820007  179.229996  2.590012  2.590012    1.445077
# 2023-11-08  182.889999  181.820007  1.069992  1.069992    0.588490
# 2023-11-09  182.410004  182.889999 -0.479996 -0.479996   -0.262451
# 2023-11-10         NaN  182.410004       NaN       NaN    0.000000
#
# [3489 rows x 5 columns]

# %%
aapl.rename(columns = {'% Change 2':'Change'}, inplace = True)

# %%
aapl
# Out:
#                   AAPL        lag1      Diff     Diff2    Change
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN       NaN
# 2010-01-05    7.656429    7.643214  0.013215  0.013215  0.172893
# 2010-01-06    7.534643    7.656429 -0.121786 -0.121786 -1.590632
# 2010-01-07    7.520714    7.534643 -0.013929 -0.013929 -0.184871
# 2010-01-08    7.570714    7.520714  0.050000  0.050000  0.664833
# ...                ...         ...       ...       ...       ...
# 2023-11-06  179.229996  176.649994  2.580002  2.580002  1.460516
# 2023-11-07  181.820007  179.229996  2.590012  2.590012  1.445077
# 2023-11-08  182.889999  181.820007  1.069992  1.069992  0.588490
# 2023-11-09  182.410004  182.889999 -0.479996 -0.479996 -0.262451
# 2023-11-10         NaN  182.410004       NaN       NaN  0.000000
#
# [3489 rows x 5 columns]

# %%
aapl.AAPL.resample("M").last()
# Out:
# Date
# 2010-01-31      6.859286
# 2010-02-28      7.307857
# 2010-03-31      8.392857
# 2010-04-30      9.324643
# 2010-05-31      9.174286
#                  ...
# 2023-07-31    196.449997
# 2023-08-31    187.869995
# 2023-09-30    171.210007
# 2023-10-31    170.770004
# 2023-11-30    182.410004
# Freq: M, Name: AAPL, Length: 167, dtype: float64

# %%
aapl.AAPL.resample("BM").last().pct_change(periods=1)
# Out:
# Date
# 2010-01-29         NaN
# 2010-02-26    0.065396
# 2010-03-31    0.148470
# 2010-04-30    0.111021
# 2010-05-31   -0.016125
#                 ...
# 2023-07-31    0.012785
# 2023-08-31   -0.043675
# 2023-09-29   -0.088678
# 2023-10-31   -0.002570
# 2023-11-30    0.068162
# Freq: BM, Name: AAPL, Length: 167, dtype: float64

# %%
aapl
# Out:
#                   AAPL        lag1      Diff     Diff2    Change
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN       NaN
# 2010-01-05    7.656429    7.643214  0.013215  0.013215  0.172893
# 2010-01-06    7.534643    7.656429 -0.121786 -0.121786 -1.590632
# 2010-01-07    7.520714    7.534643 -0.013929 -0.013929 -0.184871
# 2010-01-08    7.570714    7.520714  0.050000  0.050000  0.664833
# ...                ...         ...       ...       ...       ...
# 2023-11-06  179.229996  176.649994  2.580002  2.580002  1.460516
# 2023-11-07  181.820007  179.229996  2.590012  2.590012  1.445077
# 2023-11-08  182.889999  181.820007  1.069992  1.069992  0.588490
# 2023-11-09  182.410004  182.889999 -0.479996 -0.479996 -0.262451
# 2023-11-10         NaN  182.410004       NaN       NaN  0.000000
#
# [3489 rows x 5 columns]

# %%
del aapl["Change"]
del aapl["Diff2"]
del aapl["Diff"]
del aapl["lag1"]

# %%
aapl
# Out:
#                   AAPL
# Date
# 2010-01-04    7.643214
# 2010-01-05    7.656429
# 2010-01-06    7.534643
# 2010-01-07    7.520714
# 2010-01-08    7.570714
# ...                ...
# 2023-11-06  179.229996
# 2023-11-07  181.820007
# 2023-11-08  182.889999
# 2023-11-09  182.410004
# 2023-11-10         NaN
#
# [3489 rows x 1 columns]

# %%
ret = aapl.pct_change().dropna()
ret
# Out:
# C:\Users\Fadi\AppData\Local\Temp\ipykernel_25916\1285041635.py:1: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   ret = aapl.pct_change().dropna()
#                 AAPL
# Date
# 2010-01-05  0.001729
# 2010-01-06 -0.015906
# 2010-01-07 -0.001849
# 2010-01-08  0.006648
# 2010-01-11 -0.008821
# ...              ...
# 2023-11-06  0.014605
# 2023-11-07  0.014451
# 2023-11-08  0.005885
# 2023-11-09 -0.002625
# 2023-11-10  0.000000
#
# [3488 rows x 1 columns]

# %%
ret.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3488 entries, 2010-01-05 to 2023-11-10
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AAPL    3488 non-null   float64
# dtypes: float64(1)
# memory usage: 54.5 KB

# %%
ret.plot(kind="hist",figsize=(12,8), bins=100)
plt.show()

# %%
daily_mean_ret=ret.mean()
daily_mean_ret
# Out:
# AAPL    0.001069
# dtype: float64

# %%
var_daily=ret.var()
var_daily
# Out:
# AAPL    0.000318
# dtype: float64

# %%
std_daily=np.sqrt(var_daily)

# %%
std_daily
# Out:
# AAPL    0.017837
# dtype: float64

# %%
ret.std()
# Out:
# AAPL    0.017837
# dtype: float64

# %%
annual_mean_ret=daily_mean_ret*252
annual_mean_ret
# Out:
# AAPL    0.269415
# dtype: float64

# %%
annual_var_return=var_daily*252
annual_var_return
# Out:
# AAPL    0.080176
# dtype: float64

# %%
annual_std_retuens=np.sqrt(annual_var_return)

# %%
annual_std_retuens
# Out:
# AAPL    0.283154
# dtype: float64

# %%
ret.std()*np.sqrt(252)
# Out:
# AAPL    0.283154
# dtype: float64

# %%
ticker=["SPY","AAPL","KO","IBM","DIS","MSFT"]

# %%
stocks = yf.download(ticker, start = "2010-01-01",end ="2021-01-01")
# Out:
# [*********************100%%**********************]  6 of 6 completed

# %%
close=stocks.loc[:,"Close"].copy()

# %%
normclose=close.div(close.iloc[0]).mul(100)

# %%
normclose.plot(figsize=(15,8),fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %%
ret=close.pct_change().dropna()
ret.head()
# Out:
#                 AAPL       DIS       IBM        KO      MSFT       SPY
# Date
# 2010-01-05  0.001729 -0.002495 -0.012080 -0.012097  0.000323  0.002647
# 2010-01-06 -0.015906 -0.005314 -0.006496 -0.000355 -0.006137  0.000704
# 2010-01-07 -0.001849  0.000314 -0.003462 -0.002485 -0.010400  0.004221
# 2010-01-08  0.006648  0.001571  0.010035 -0.018509  0.006897  0.003328
# 2010-01-11 -0.008821 -0.016311 -0.010470  0.020308 -0.012720  0.001397

# %%
ret.describe().T
# Out:
#        count      mean       std       min       25%       50%       75%  \
# AAPL  2768.0  0.001191  0.017843 -0.128647 -0.007123  0.000903  0.010379
# DIS   2768.0  0.000749  0.015717 -0.129846 -0.006210  0.000629  0.007901
# IBM   2768.0  0.000082  0.014132 -0.128507 -0.006321  0.000287  0.006743
# KO    2768.0  0.000298  0.011088 -0.096725 -0.004698  0.000438  0.005706
# MSFT  2768.0  0.000841  0.016012 -0.147390 -0.006939  0.000654  0.008636
# SPY   2768.0  0.000491  0.010909 -0.109424 -0.003532  0.000637  0.005421
#
#            max
# AAPL  0.119808
# DIS   0.144123
# IBM   0.113010
# KO    0.064796
# MSFT  0.142169
# SPY   0.090603

# %%
summary=ret.describe().T.loc[:,["mean","std"]]
summary
# Out:
#           mean       std
# AAPL  0.001191  0.017843
# DIS   0.000749  0.015717
# IBM   0.000082  0.014132
# KO    0.000298  0.011088
# MSFT  0.000841  0.016012
# SPY   0.000491  0.010909

# %%
summary["mean"]=summary["mean"]*252
summary["std"]=summary["std"]*np.sqrt(252)
summary
# Out:
#           mean       std
# AAPL  0.300134  0.283242
# DIS   0.188696  0.249504
# IBM   0.020648  0.224345
# KO    0.075091  0.176009
# MSFT  0.211915  0.254185
# SPY   0.123754  0.173170

# %%
# %matplotlib inline
summary.plot.scatter(x="std",y="mean",figsize=(12,8),s=50,fontsize=15)
for i in summary.index:
    plt.annotate(i,xy=(summary.loc[i,"std"]+0.002,summary.loc[i,"mean"]+0.002),size=15)
plt.xlabel("Annual risk(std)",fontsize = 15)
plt.ylabel("Annual return",fontsize = 15)
plt.title("Risk/return",fontsize=25)
plt.show()

# %% [markdown]
# ## Correlation and Covariance

# %%
ret
# Out:
#                 AAPL       DIS       IBM        KO      MSFT       SPY
# Date
# 2010-01-05  0.001729 -0.002495 -0.012080 -0.012097  0.000323  0.002647
# 2010-01-06 -0.015906 -0.005314 -0.006496 -0.000355 -0.006137  0.000704
# 2010-01-07 -0.001849  0.000314 -0.003462 -0.002485 -0.010400  0.004221
# 2010-01-08  0.006648  0.001571  0.010035 -0.018509  0.006897  0.003328
# 2010-01-11 -0.008821 -0.016311 -0.010470  0.020308 -0.012720  0.001397
# ...              ...       ...       ...       ...       ...       ...
# 2020-12-24  0.007712  0.001037  0.006376  0.006782  0.007827  0.003890
# 2020-12-28  0.035766  0.029529  0.001043  0.013473  0.009921  0.008591
# 2020-12-29 -0.013315 -0.008722 -0.008172 -0.000554 -0.003601 -0.001908
# 2020-12-30 -0.008527  0.021827  0.004362  0.005727 -0.011019  0.001427
# 2020-12-31 -0.007703  0.000055  0.012385  0.007348  0.003338  0.005081
#
# [2768 rows x 6 columns]

# %%
ret.cov()
# Out:
#           AAPL       DIS       IBM        KO      MSFT       SPY
# AAPL  0.000318  0.000115  0.000110  0.000067  0.000158  0.000128
# DIS   0.000115  0.000247  0.000111  0.000085  0.000121  0.000121
# IBM   0.000110  0.000111  0.000200  0.000079  0.000121  0.000108
# KO    0.000067  0.000085  0.000079  0.000123  0.000076  0.000077
# MSFT  0.000158  0.000121  0.000121  0.000076  0.000256  0.000130
# SPY   0.000128  0.000121  0.000108  0.000077  0.000130  0.000119

# %%
ret.corr()
# Out:
#           AAPL       DIS       IBM        KO      MSFT       SPY
# AAPL  1.000000  0.408513  0.436100  0.339213  0.554051  0.659557
# DIS   0.408513  1.000000  0.497775  0.486514  0.480457  0.706726
# IBM   0.436100  0.497775  1.000000  0.502436  0.533130  0.703342
# KO    0.339213  0.486514  0.502436  1.000000  0.429749  0.639324
# MSFT  0.554051  0.480457  0.533130  0.429749  1.000000  0.744601
# SPY   0.659557  0.706726  0.703342  0.639324  0.744601  1.000000

# %%
import seaborn as sns

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale=1.4)
sns.heatmap(ret.corr(),cmap="Reds",annot=True,annot_kws={"size":15},vmax=0.6)
plt.show()

# %% [markdown]
# # Simple returns and log returns

# %%
df = pd.DataFrame(index=[2016,2017,2018],data=[100,50,95],columns=["Price"])

# %%
df
# Out:
#       Price
# 2016    100
# 2017     50
# 2018     95

# %%
simplereturns=df.pct_change().dropna()
simplereturns
# Out:
#       Price
# 2017   -0.5
# 2018    0.9

# %%
simplereturns.mean()
# Out:
# Price    0.2
# dtype: float64

# %%
100*1.2*1.2
# Out:
# 144.0

# %%
#Mean returns are misleading as crazy

# %%
logreturns=np.log(df/df.shift(1)).dropna()
logreturns
# Out:
#          Price
# 2017 -0.693147
# 2018  0.641854

# %%
logreturns.mean()
# Out:
# Price   -0.025647
# dtype: float64

# %%
100*np.exp(logreturns.mean()*2)
# Out:
# Price    95.0
# dtype: float64

# %%
SPY = yf.download("SPY")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
spy=SPY.Close.to_frame()

# %%
spy
# Out:
#                  Close
# Date
# 1993-01-29   43.937500
# 1993-02-01   44.250000
# 1993-02-02   44.343750
# 1993-02-03   44.812500
# 1993-02-04   45.000000
# ...                ...
# 2023-11-06  435.690002
# 2023-11-07  436.929993
# 2023-11-08  437.250000
# 2023-11-09  433.839996
# 2023-11-10  439.500000
#
# [7753 rows x 1 columns]

# %%
spy.plot(figsize=(12,8),fontsize=15)
plt.legend(loc="upper left", fontsize=15)
plt.show()

# %%
spy_roll=spy.rolling(window=10)

# %%
spy_roll=spy_roll.mean()

# %%
spy_roll.head(15)
# Out:
#                 Close
# Date
# 1993-01-29        NaN
# 1993-02-01        NaN
# 1993-02-02        NaN
# 1993-02-03        NaN
# 1993-02-04        NaN
# 1993-02-05        NaN
# 1993-02-08        NaN
# 1993-02-09        NaN
# 1993-02-10        NaN
# 1993-02-11  44.659375
# 1993-02-12  44.725000
# 1993-02-16  44.646875
# 1993-02-17  44.556250
# 1993-02-18  44.415625
# 1993-02-19  44.271875

# %%
spy.rolling(window=10).median()
# Out:
#                  Close
# Date
# 1993-01-29         NaN
# 1993-02-01         NaN
# 1993-02-02         NaN
# 1993-02-03         NaN
# 1993-02-04         NaN
# ...                ...
# 2023-11-06  420.430008
# 2023-11-07  420.430008
# 2023-11-08  426.710007
# 2023-11-09  432.300003
# 2023-11-10  434.264999
#
# [7753 rows x 1 columns]

# %%
spy.rolling(window=10).max()
# Out:
#                  Close
# Date
# 1993-01-29         NaN
# 1993-02-01         NaN
# 1993-02-02         NaN
# 1993-02-03         NaN
# 1993-02-04         NaN
# ...                ...
# 2023-11-06  435.690002
# 2023-11-07  436.929993
# 2023-11-08  437.250000
# 2023-11-09  437.250000
# 2023-11-10  439.500000
#
# [7753 rows x 1 columns]

# %%
spy.rolling(window=10,min_periods=5).max()
# Out:
#                  Close
# Date
# 1993-01-29         NaN
# 1993-02-01         NaN
# 1993-02-02         NaN
# 1993-02-03         NaN
# 1993-02-04   45.000000
# ...                ...
# 2023-11-06  435.690002
# 2023-11-07  436.929993
# 2023-11-08  437.250000
# 2023-11-09  437.250000
# 2023-11-10  439.500000
#
# [7753 rows x 1 columns]

# %%
spy
# Out:
#                  Close
# Date
# 1993-01-29   43.937500
# 1993-02-01   44.250000
# 1993-02-02   44.343750
# 1993-02-03   44.812500
# 1993-02-04   45.000000
# ...                ...
# 2023-11-06  435.690002
# 2023-11-07  436.929993
# 2023-11-08  437.250000
# 2023-11-09  433.839996
# 2023-11-10  439.500000
#
# [7753 rows x 1 columns]

# %%
spy["SMA50"]=spy.rolling(window=50,min_periods=50).mean()

# %%
spy
# Out:
#                  Close       SMA50
# Date
# 1993-01-29   43.937500         NaN
# 1993-02-01   44.250000         NaN
# 1993-02-02   44.343750         NaN
# 1993-02-03   44.812500         NaN
# 1993-02-04   45.000000         NaN
# ...                ...         ...
# 2023-11-06  435.690002  433.603801
# 2023-11-07  436.929993  433.487201
# 2023-11-08  437.250000  433.249001
# 2023-11-09  433.839996  432.905601
# 2023-11-10  439.500000  432.688600
#
# [7753 rows x 2 columns]

# %%
spy.plot(figsize=(12,8),fontsize=15)
plt.legend(loc="upper left", fontsize=15)
plt.show()

# %%
spy["SMA200"]=spy.Close.rolling(window=200,min_periods=200).mean()
spy
# Out:
#                  Close       SMA50      SMA200
# Date
# 1993-01-29   43.937500         NaN         NaN
# 1993-02-01   44.250000         NaN         NaN
# 1993-02-02   44.343750         NaN         NaN
# 1993-02-03   44.812500         NaN         NaN
# 1993-02-04   45.000000         NaN         NaN
# ...                ...         ...         ...
# 2023-11-06  435.690002  433.603801  423.954751
# 2023-11-07  436.929993  433.487201  424.136251
# 2023-11-08  437.250000  433.249001  424.321501
# 2023-11-09  433.839996  432.905601  424.488951
# 2023-11-10  439.500000  432.688600  424.662701
#
# [7753 rows x 3 columns]

# %%
spy.plot(figsize=(12,8),fontsize=15)
plt.legend(loc="upper left", fontsize=15)
plt.show()

# %%
spy["EMA100"]=spy.Close.ewm(span=100,min_periods=100).mean()

# %%
spy
# Out:
#                  Close       SMA50      SMA200      EMA100
# Date
# 1993-01-29   43.937500         NaN         NaN         NaN
# 1993-02-01   44.250000         NaN         NaN         NaN
# 1993-02-02   44.343750         NaN         NaN         NaN
# 1993-02-03   44.812500         NaN         NaN         NaN
# 1993-02-04   45.000000         NaN         NaN         NaN
# ...                ...         ...         ...         ...
# 2023-11-06  435.690002  433.603801  423.954751  431.601680
# 2023-11-07  436.929993  433.487201  424.136251  431.707191
# 2023-11-08  437.250000  433.249001  424.321501  431.816950
# 2023-11-09  433.839996  432.905601  424.488951  431.857010
# 2023-11-10  439.500000  432.688600  424.662701  432.008356
#
# [7753 rows x 4 columns]

# %%
spy.plot(figsize=(12,8),fontsize=15)
plt.legend(loc="upper left", fontsize=15)
plt.show()

# %%
spy["Day"]=spy.index.day_name()

# %%
spy["Quarter"]=spy.index.quarter

# %%
SPY = yf.download("SPY")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
spy=SPY.Close.to_frame()

# %%
all_days=pd.date_range(start="2010-12-31",end="2020-01-01",freq="D")
all_days
# Out:
# DatetimeIndex(['2010-12-31', '2011-01-01', '2011-01-02', '2011-01-03',
#                '2011-01-04', '2011-01-05', '2011-01-06', '2011-01-07',
#                '2011-01-08', '2011-01-09',
#                ...
#                '2019-12-23', '2019-12-24', '2019-12-25', '2019-12-26',
#                '2019-12-27', '2019-12-28', '2019-12-29', '2019-12-30',
#                '2019-12-31', '2020-01-01'],
#               dtype='datetime64[ns]', length=3289, freq='D')

# %%
spy
# Out:
#                  Close
# Date
# 1993-01-29   43.937500
# 1993-02-01   44.250000
# 1993-02-02   44.343750
# 1993-02-03   44.812500
# 1993-02-04   45.000000
# ...                ...
# 2023-11-06  435.690002
# 2023-11-07  436.929993
# 2023-11-08  437.250000
# 2023-11-09  433.839996
# 2023-11-10  439.519897
#
# [7753 rows x 1 columns]

# %%
spy=spy.reindex(all_days)

# %%
spy
# Out:
#                  Close
# 2010-12-31  125.750000
# 2011-01-01         NaN
# 2011-01-02         NaN
# 2011-01-03  127.050003
# 2011-01-04  126.980003
# ...                ...
# 2019-12-28         NaN
# 2019-12-29         NaN
# 2019-12-30  321.079987
# 2019-12-31  321.859985
# 2020-01-01         NaN
#
# [3289 rows x 1 columns]

# %%
spy.fillna(method="ffill")
# Out:
# C:\Users\Fadi\AppData\Local\Temp\ipykernel_25916\3731869003.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   spy.fillna(method="ffill")
#                  Close
# 2010-12-31  125.750000
# 2011-01-01  125.750000
# 2011-01-02  125.750000
# 2011-01-03  127.050003
# 2011-01-04  126.980003
# ...                ...
# 2019-12-28  322.859985
# 2019-12-29  322.859985
# 2019-12-30  321.079987
# 2019-12-31  321.859985
# 2020-01-01  321.859985
#
# [3289 rows x 1 columns]

# %%
spy.fillna(method="bfill")
# Out:
# C:\Users\Fadi\AppData\Local\Temp\ipykernel_25916\1752721331.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   spy.fillna(method="bfill")
#                  Close
# 2010-12-31  125.750000
# 2011-01-01  127.050003
# 2011-01-02  127.050003
# 2011-01-03  127.050003
# 2011-01-04  126.980003
# ...                ...
# 2019-12-28  321.079987
# 2019-12-29  321.079987
# 2019-12-30  321.079987
# 2019-12-31  321.859985
# 2020-01-01         NaN
#
# [3289 rows x 1 columns]

# %%
SPY = yf.download("SPY",interval="1wk")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
SPY
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1993-01-25   43.968750   43.968750   43.750000   43.937500   24.941370
# 1993-02-01   43.968750   45.093750   43.968750   44.968750   25.526791
# 1993-02-08   44.968750   45.125000   44.531250   44.593750   25.313923
# 1993-02-15   44.468750   44.468750   42.812500   43.562500   24.728533
# 1993-02-22   43.687500   44.437500   43.468750   44.406250   25.207478
# ...                ...         ...         ...         ...         ...
# 2023-10-09  427.579987  437.339996  427.010010  431.500000  431.500000
# 2023-10-16  433.820007  438.140015  421.079987  421.190002  421.190002
# 2023-10-23  419.609985  424.820007  409.209991  410.679993  410.679993
# 2023-10-30  413.559998  436.290009  412.220001  434.690002  434.690002
# 2023-11-06  435.470001  439.769989  433.399994  439.519897  439.519897
#
#                Volume
# Date
# 1993-01-25    1003200
# 1993-02-01    2234800
# 1993-02-08    1159800
# 1993-02-15     998700
# 1993-02-22    1024300
# ...               ...
# 2023-10-09  397730700
# 2023-10-16  489486500
# 2023-10-23  487347000
# 2023-10-30  459345700
# 2023-11-06  325918636
#
# [1607 rows x 6 columns]

# %% [markdown]
# ## Cummaltive Returns, Drawdowns etc..

# %%
apple=yf.download("AAPL")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
apple=apple.Close.to_frame()

# %%
apple
# Out:
#                  Close
# Date
# 1980-12-12    0.128348
# 1980-12-15    0.121652
# 1980-12-16    0.112723
# 1980-12-17    0.115513
# 1980-12-18    0.118862
# ...                ...
# 2023-11-03  176.649994
# 2023-11-06  179.229996
# 2023-11-07  181.820007
# 2023-11-08  182.889999
# 2023-11-09  182.410004
#
# [10819 rows x 1 columns]

# %%
apple["d_returns"]=np.log(apple.div(apple.shift(1)))

# %%
apple
# Out:
#                  Close  d_returns
# Date
# 1980-12-12    0.128348        NaN
# 1980-12-15    0.121652  -0.053581
# 1980-12-16    0.112723  -0.076231
# 1980-12-17    0.115513   0.024450
# 1980-12-18    0.118862   0.028580
# ...                ...        ...
# 2023-11-03  176.649994  -0.005195
# 2023-11-06  179.229996   0.014500
# 2023-11-07  181.820007   0.014347
# 2023-11-08  182.889999   0.005868
# 2023-11-09  182.410004  -0.002628
#
# [10819 rows x 2 columns]

# %%
apple.dropna(inplace=True)

# %%
apple
# Out:
#                  Close  d_returns
# Date
# 1980-12-15    0.121652  -0.053581
# 1980-12-16    0.112723  -0.076231
# 1980-12-17    0.115513   0.024450
# 1980-12-18    0.118862   0.028580
# 1980-12-19    0.126116   0.059239
# ...                ...        ...
# 2023-11-03  176.649994  -0.005195
# 2023-11-06  179.229996   0.014500
# 2023-11-07  181.820007   0.014347
# 2023-11-08  182.889999   0.005868
# 2023-11-09  182.410004  -0.002628
#
# [10818 rows x 2 columns]

# %%
apple.d_returns.sum()
# Out:
# 7.25926693029484

# %%
np.exp(apple.d_returns.sum())
# Out:
# 1421.214306081495

# %%
apple["cummreturns"]=apple.d_returns.cumsum().apply(np.exp)

# %%
apple
# Out:
#                  Close  d_returns  cummreturns
# Date
# 1980-12-15    0.121652  -0.053581     0.947829
# 1980-12-16    0.112723  -0.076231     0.878261
# 1980-12-17    0.115513   0.024450     0.899998
# 1980-12-18    0.118862   0.028580     0.926092
# 1980-12-19    0.126116   0.059239     0.982610
# ...                ...        ...          ...
# 2023-11-03  176.649994  -0.005195  1376.336240
# 2023-11-06  179.229996   0.014500  1396.437854
# 2023-11-07  181.820007   0.014347  1416.617457
# 2023-11-08  182.889999   0.005868  1424.954105
# 2023-11-09  182.410004  -0.002628  1421.214306
#
# [10818 rows x 3 columns]

# %%
apple.cummreturns.plot(figsize=(12,8),title="APPLe buy and hold", fontsize=12)
plt.show()

# %%
apple.d_returns.mean()*252
# Out:
# 0.16910105994031238

# %%
apple.d_returns.std()*np.sqrt(252)
# Out:
# 0.45221090765292854

# %%
# how to calculate drawdowns
apple["cummmax"]=apple.cummreturns.cummax()

# %%
apple
# Out:
#                  Close  d_returns  cummreturns      cummmax
# Date
# 1980-12-15    0.121652  -0.053581     0.947829     0.947829
# 1980-12-16    0.112723  -0.076231     0.878261     0.947829
# 1980-12-17    0.115513   0.024450     0.899998     0.947829
# 1980-12-18    0.118862   0.028580     0.926092     0.947829
# 1980-12-19    0.126116   0.059239     0.982610     0.982610
# ...                ...        ...          ...          ...
# 2023-11-03  176.649994  -0.005195  1376.336240  1530.604356
# 2023-11-06  179.229996   0.014500  1396.437854  1530.604356
# 2023-11-07  181.820007   0.014347  1416.617457  1530.604356
# 2023-11-08  182.889999   0.005868  1424.954105  1530.604356
# 2023-11-09  182.410004  -0.002628  1421.214306  1530.604356
#
# [10818 rows x 4 columns]

# %%
apple[["cummreturns","cummmax"]].plot(figsize=(12,8),title="APPLe buy and hold+cummmax", fontsize=12)
plt.show()

# %%
apple["drawdown"]=apple["cummmax"]-apple["cummreturns"]

# %%
apple
# Out:
#                  Close  d_returns  cummreturns      cummmax    drawdown
# Date
# 1980-12-15    0.121652  -0.053581     0.947829     0.947829    0.000000
# 1980-12-16    0.112723  -0.076231     0.878261     0.947829    0.069569
# 1980-12-17    0.115513   0.024450     0.899998     0.947829    0.047831
# 1980-12-18    0.118862   0.028580     0.926092     0.947829    0.021738
# 1980-12-19    0.126116   0.059239     0.982610     0.982610    0.000000
# ...                ...        ...          ...          ...         ...
# 2023-11-03  176.649994  -0.005195  1376.336240  1530.604356  154.268116
# 2023-11-06  179.229996   0.014500  1396.437854  1530.604356  134.166502
# 2023-11-07  181.820007   0.014347  1416.617457  1530.604356  113.986898
# 2023-11-08  182.889999   0.005868  1424.954105  1530.604356  105.650250
# 2023-11-09  182.410004  -0.002628  1421.214306  1530.604356  109.390049
#
# [10818 rows x 5 columns]

# %%
apple.drawdown.max()
# Out:
# 444.02718404402026

# %%
apple.drawdown.idxmax()
# Out:
# Timestamp('2023-01-05 00:00:00')

# %%
apple.loc[(apple.index<='2020-09-18')]
# Out:
#                  Close  d_returns  cummreturns      cummmax    drawdown
# Date
# 1980-12-15    0.121652  -0.053581     0.947829     0.947829    0.000000
# 1980-12-16    0.112723  -0.076231     0.878261     0.947829    0.069569
# 1980-12-17    0.115513   0.024450     0.899998     0.947829    0.047831
# 1980-12-18    0.118862   0.028580     0.926092     0.947829    0.021738
# 1980-12-19    0.126116   0.059239     0.982610     0.982610    0.000000
# ...                ...        ...          ...          ...         ...
# 2020-09-14  115.360001   0.029559   898.806425  1045.438964  146.632539
# 2020-09-15  115.540001   0.001559   900.208864  1045.438964  145.230099
# 2020-09-16  112.129997  -0.029958   873.640442  1045.438964  171.798522
# 2020-09-17  110.339996  -0.016092   859.693976  1045.438964  185.744988
# 2020-09-18  106.839996  -0.032234   832.424364  1045.438964  213.014600
#
# [10027 rows x 5 columns]

# %%
apple["drawdown%"]=(apple["cummmax"]-apple["cummreturns"])/apple["cummmax"]

# %%
apple
# Out:
#                  Close  d_returns  cummreturns      cummmax    drawdown  \
# Date
# 1980-12-15    0.121652  -0.053581     0.947829     0.947829    0.000000
# 1980-12-16    0.112723  -0.076231     0.878261     0.947829    0.069569
# 1980-12-17    0.115513   0.024450     0.899998     0.947829    0.047831
# 1980-12-18    0.118862   0.028580     0.926092     0.947829    0.021738
# 1980-12-19    0.126116   0.059239     0.982610     0.982610    0.000000
# ...                ...        ...          ...          ...         ...
# 2023-11-03  176.649994  -0.005195  1376.336240  1530.604356  154.268116
# 2023-11-06  179.229996   0.014500  1396.437854  1530.604356  134.166502
# 2023-11-07  181.820007   0.014347  1416.617457  1530.604356  113.986898
# 2023-11-08  182.889999   0.005868  1424.954105  1530.604356  105.650250
# 2023-11-09  182.410004  -0.002628  1421.214306  1530.604356  109.390049
#
#             drawdown%
# Date
# 1980-12-15   0.000000
# 1980-12-16   0.073398
# 1980-12-17   0.050464
# 1980-12-18   0.022934
# 1980-12-19   0.000000
# ...               ...
# 2023-11-03   0.100789
# 2023-11-06   0.087656
# 2023-11-07   0.074472
# 2023-11-08   0.069025
# 2023-11-09   0.071469
#
# [10818 rows x 6 columns]

# %%
apple["drawdown%"].max()
# Out:
# 0.82216567924191

# %%
apple["drawdown%"].idxmax()
# Out:
# Timestamp('1997-12-23 00:00:00')

# %%
apple.loc[(apple.index<='1997-12-23')]
# Out:
#                Close  d_returns  cummreturns   cummmax  drawdown  drawdown%
# Date
# 1980-12-15  0.121652  -0.053581     0.947829  0.947829  0.000000   0.000000
# 1980-12-16  0.112723  -0.076231     0.878261  0.947829  0.069569   0.073398
# 1980-12-17  0.115513   0.024450     0.899998  0.947829  0.047831   0.050464
# 1980-12-18  0.118862   0.028580     0.926092  0.947829  0.021738   0.022934
# 1980-12-19  0.126116   0.059239     0.982610  0.982610  0.000000   0.000000
# ...              ...        ...          ...       ...       ...        ...
# 1997-12-17  0.124442  -0.026549     0.969567  5.060882  4.091315   0.808419
# 1997-12-18  0.123326  -0.009008     0.960872  5.060882  4.100010   0.810137
# 1997-12-19  0.122210  -0.009090     0.952177  5.060882  4.108705   0.811856
# 1997-12-22  0.118862  -0.027778     0.926092  5.060882  4.134790   0.817010
# 1997-12-23  0.115513  -0.028580     0.899998  5.060882  4.160883   0.822166
#
# [4306 rows x 6 columns]

# %% [markdown]
# ## SMA Strategy

# %%
data=apple.Close.loc[(apple.index>='1991-01-01')]

# %%
data=data.to_frame()

# %%
data
# Out:
#                  Close
# Date
# 1991-01-02    0.388393
# 1991-01-03    0.383929
# 1991-01-04    0.386161
# 1991-01-07    0.386161
# 1991-01-08    0.386161
# ...                ...
# 2023-11-03  176.649994
# 2023-11-06  179.229996
# 2023-11-07  181.820007
# 2023-11-08  182.889999
# 2023-11-09  182.410004
#
# [8278 rows x 1 columns]

# %%
sma_s=50
sma_l=100

# %%
data["sma_s"]=data.Close.rolling(sma_s).mean()
data["sma_l"]=data.Close.rolling(sma_l).mean()

# %%
data
# Out:
#                  Close       sma_s       sma_l
# Date
# 1991-01-02    0.388393         NaN         NaN
# 1991-01-03    0.383929         NaN         NaN
# 1991-01-04    0.386161         NaN         NaN
# 1991-01-07    0.386161         NaN         NaN
# 1991-01-08    0.386161         NaN         NaN
# ...                ...         ...         ...
# 2023-11-03  176.649994  176.587801  181.677801
# 2023-11-06  179.229996  176.600201  181.630601
# 2023-11-07  181.820007  176.632801  181.588701
# 2023-11-08  182.889999  176.608201  181.568401
# 2023-11-09  182.410004  176.503401  181.542401
#
# [8278 rows x 3 columns]

# %%
data.plot(figsize=(12,8),title="AAPLE - SMA{} | SMA{}".format(sma_s,sma_l), fontsize=12)
# Out:
# <Axes: title={'center': 'AAPLE - SMA50 | SMA100'}, xlabel='Date'>

# %%
data.loc["2016"].plot(figsize=(12,8),title="AAPLE - SMA{} | SMA{}".format(sma_s,sma_l), fontsize=12)
# Out:
# <Axes: title={'center': 'AAPLE - SMA50 | SMA100'}, xlabel='Date'>

# %%
data.dropna(inplace=True)

# %%
data
# Out:
#                  Close       sma_s       sma_l
# Date
# 1991-05-23    0.402902    0.534420    0.513326
# 1991-05-24    0.409598    0.530960    0.513538
# 1991-05-28    0.410714    0.527344    0.513806
# 1991-05-29    0.419643    0.523638    0.514141
# 1991-05-30    0.425223    0.519732    0.514531
# ...                ...         ...         ...
# 2023-11-03  176.649994  176.587801  181.677801
# 2023-11-06  179.229996  176.600201  181.630601
# 2023-11-07  181.820007  176.632801  181.588701
# 2023-11-08  182.889999  176.608201  181.568401
# 2023-11-09  182.410004  176.503401  181.542401
#
# [8179 rows x 3 columns]

# %%
data["position"]=np.where(data["sma_s"]>data["sma_l"],1,-1)

# %%
data
# Out:
#                  Close       sma_s       sma_l  position
# Date
# 1991-05-23    0.402902    0.534420    0.513326         1
# 1991-05-24    0.409598    0.530960    0.513538         1
# 1991-05-28    0.410714    0.527344    0.513806         1
# 1991-05-29    0.419643    0.523638    0.514141         1
# 1991-05-30    0.425223    0.519732    0.514531         1
# ...                ...         ...         ...       ...
# 2023-11-03  176.649994  176.587801  181.677801        -1
# 2023-11-06  179.229996  176.600201  181.630601        -1
# 2023-11-07  181.820007  176.632801  181.588701        -1
# 2023-11-08  182.889999  176.608201  181.568401        -1
# 2023-11-09  182.410004  176.503401  181.542401        -1
#
# [8179 rows x 4 columns]

# %%
data.loc["2016",["sma_s","sma_l","position"]].plot(figsize=(12,8),title="AAPLE - SMA{} | SMA{}".format(sma_s,sma_l), fontsize=12,secondary_y="position")
# Out:
# <Axes: title={'center': 'AAPLE - SMA50 | SMA100'}, xlabel='Date'>

# %%
data["returnsb&h"]=np.log(data.Close.div(data.Close.shift(1)))

# %%
data["strategy"]=data["returnsb&h"]*data.position.shift(1)

# %%
data
# Out:
#                  Close       sma_s       sma_l  position  returnsb&h  strategy
# Date
# 1991-05-23    0.402902    0.534420    0.513326         1         NaN       NaN
# 1991-05-24    0.409598    0.530960    0.513538         1    0.016483  0.016483
# 1991-05-28    0.410714    0.527344    0.513806         1    0.002721  0.002721
# 1991-05-29    0.419643    0.523638    0.514141         1    0.021507  0.021507
# 1991-05-30    0.425223    0.519732    0.514531         1    0.013209  0.013209
# ...                ...         ...         ...       ...         ...       ...
# 2023-11-03  176.649994  176.587801  181.677801        -1   -0.005195  0.005195
# 2023-11-06  179.229996  176.600201  181.630601        -1    0.014500 -0.014500
# 2023-11-07  181.820007  176.632801  181.588701        -1    0.014347 -0.014347
# 2023-11-08  182.889999  176.608201  181.568401        -1    0.005868 -0.005868
# 2023-11-09  182.410004  176.503401  181.542401        -1   -0.002628  0.002628
#
# [8179 rows x 6 columns]

# %%
data.dropna(inplace=True)

# %%
data[["returnsb&h","strategy"]].sum()
# Out:
# returnsb&h    6.115319
# strategy      2.020744
# dtype: float64

# %%
data[["returnsb&h","strategy"]].sum().apply(np.exp) # what 1$ will be
# Out:
# returnsb&h    452.740370
# strategy        7.543933
# dtype: float64

# %%
data[["returnsb&h","strategy"]].std()*np.sqrt(252) #annyal std
# Out:
# returnsb&h    0.435743
# strategy      0.435887
# dtype: float64

# %%
data.Close.plot(figsize=(12,8))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ## Strategy adjusted with long bias

# %%
data["position2"]=np.where(data["sma_s"]>data["sma_l"],1,0)

# %%
data["strategy2"]=data["returnsb&h"]*data.position2.shift(1)

# %%
data.dropna(inplace=True)

# %%
data[["returnsb&h","strategy2"]].sum()
# Out:
# returnsb&h    6.098836
# strategy2     4.051548
# dtype: float64

# %%
data[["returnsb&h","strategy2"]].sum().apply(np.exp) # what 1$ will be
# Out:
# returnsb&h    445.339105
# strategy2      57.486403
# dtype: float64

# %%
data[["returnsb&h","strategy2"]].std()*np.sqrt(252)
# Out:
# returnsb&h    0.435761
# strategy2     0.336881
# dtype: float64

# %%
## Strategy 2 is better than strategy 1
data[["strategy","strategy2"]].std()*np.sqrt(252)
# Out:
# strategy     0.435904
# strategy2    0.336881
# dtype: float64

# %% [markdown]
# # Creating our first function

# %%
def test_strategy(stock,start,end,SMA):
    df=yf.download(stock,start=start,end=end)
    data=df.Close.to_frame()
    data["returns"]=np.log(data.Close.div(data.Close.shift(1)))
    data["SMA_S"]=data.Close.rolling(int(SMA[0])).mean()
    data["SMA_L"]=data.Close.rolling(int(SMA[1])).mean()
    data.dropna(inplace=True)
    
    data["position"]=np.where(data["SMA_S"]>data["SMA_L"],1,-1)
    data["strategy"]=data["returns"]*data.position.shift(1)
    data.dropna(inplace=True)
    ret=np.exp(data["strategy"].sum())
    std= data["strategy"].std()*np.sqrt(252)
    
    return ret,std

# %%
test_strategy("SPY","2000-01-01","2020-01-01",(50,200))
# Out:
# [*********************100%%**********************]  1 of 1 completed
# (4.766371508372407, 0.18787947185958592)

# %% [markdown]
# ## Creating our first class

# %%
class SMABacktester():
    def __init__(self,symbol,SMA_S, SMA_L,start,end):
        self.symbol=symbol
        self.SMA_S=SMA_S
        self.SMA_L=SMA_L
        self.start=start
        self.end=end
        self.results=None
        self.get_data()
        
    def get_data(self):
        df=yf.download(self.symbol,start=self.start,end=self.end)
        data=df.Close.to_frame()
        data["returns"]=np.log(data.Close.div(data.Close.shift(1)))
        data["SMA_S"]=data.Close.rolling(self.SMA_S).mean()
        data["SMA_L"]=data.Close.rolling(self.SMA_L).mean()
        data.dropna(inplace=True)
        self.data2=data
        
        return data
    
    def test_results(self):
        data=self.data2.copy().dropna()
        data["position"]=np.where(data["SMA_S"]>data["SMA_L"],1,-1)
        data["strategy"]=data["returns"]*data.position.shift(1)
        data.dropna(inplace=True)
        data["returnsbh"]=data["returns"].cumsum().apply(np.exp)
        data["returnsstrategy"]=data["strategy"].cumsum().apply(np.exp)
        perf=data["returnsstrategy"].iloc[-1]
        outperf=perf-data["returnsbh"].iloc[-1]
        self.results=data
        
        ret=np.exp(data["strategy"].sum())
        std= data["strategy"].std()*np.sqrt(252)
    
        #return ret,std
        return round(perf,6), round(outperf,6)
    
    def plot_results(self):
        if self.results is None:
            print("Run the test please")
        else:
            title="{}| SMA_S={} | SMA_L{}".format(self.symbol,self.SMA_S, self.SMA_L)
            self.results[["returnsbh","returnsstrategy"]].plot(title=title, figsize=(12,8))

# %%
tester= SMABacktester("SPY",50,100, "2000-01-01","2020-01-01")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
tester.test_results()
# Out:
# (2.592726, 0.297824)

# %%
tester.plot_results()
